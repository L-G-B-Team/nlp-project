# %%
import pandas as pd
import matplotlib.pyplot as plt

from importlib import reload

import acquire as a 
import prepare as p
import explore as e

# %%
df = a.acquire_readmes()

# %%
EXTRA_CODE = ["'", "&#9;", "use"]

# %%
df.readme_contents = df.readme_contents.astype('str')

# %%
reload(p)
# Out:
# <module 'prepare' from '/Users/fostermark/codeup-data-science/nlp-project/prepare.py'>

# %%
df = p.prep_df_for_nlp(df,'readme_contents',extra_words=[],exclude_words=[])

# %%
df[df.readme_contents.str.contains('你')]
# Out:
#                                          repo    language  \
# 18                Trinea/android-open-project         NaN
# 48                 fex-team/kityminder-editor  JavaScript
# 49   pablohpsilva/vuejs-component-style-guide         NaN
# 52                      facert/awesome-spider         NaN
# 59              PanJiaChen/vue-admin-template  JavaScript
# ..                                        ...         ...
# 603         jobbole/awesome-programming-books         NaN
# 650                       nusr/hacker-laws-zh         NaN
# 662    selfteaching/the-craft-of-selfteaching       Other
# 663             CarGuo/gsy_github_app_flutter       Other
# 676              BoyceLig/Clash_Chinese_Patch  JavaScript
#
#                                        readme_contents  \
# 18   Android 开源项目分类汇总，最新最全版可见 [codekk.com](https://...
# 48   KityMinder Editor\n==========\n\n## 简介\n\nKity...
# 49   # Vue.js 组件编码规范\n\n> 这个 [链接](https://github.co...
# 52   # awesome-spider\n\n--------------------------...
# 59   # vue-admin-template\n\n> 这是一个极简的 vue admin 管理...
# ..                                                 ...
# 603  # 经典编程书籍大全\n\n100+ 经典技术书籍，涵盖：计算机系统与网络、系统架构、算法与...
# 650  [![Build Status](https://travis-ci.org/nusr/ha...
# 662  # the-craft-of-selfteaching\n\n> One has no fu...
# 663  ![](./logo.png)\n\n[![Github Actions](https://...
# 676  # Clash_Chinese_Patch\n\n[![](https://img.shie...
#
#                                                  clean  \
# 18   android codekkcomhttpspcodekkcom english versi...
# 48   kityminder editor kityminder editor fexhttpsgi...
# 49   vuejs httpsgithubcomsqrthreevuejscomponentstyl...
# 52   awesomespider hrefhttpwwwipideanetutmsourcefac...
# 59   vueadmintemplate vue admin element ui axios ic...
# ..                                                 ...
# 603  100 httpblogjobbolecomtagbook100 issues httpsw...
# 650  build statushttpstravisciorgnusrhackerlawszhsv...
# 662  thecraftofselfteaching one future one couldnt ...
# 663  logopng github actionshttpsgithubcomcarguogsyg...
# 676  clashchinesepatch httpsimgshieldsiobadgetelegr...
#
#                                                   stem  \
# 18   android codekkcomhttpspcodekkcom english versi...
# 48   kitymind editor kitymind editor fexhttpsgithub...
# 49   vuej httpsgithubcomsqrthreevuejscomponentstyle...
# 52   awesomespid hrefhttpwwwipideanetutmsourcefacer...
# 59   vueadmintempl vue admin element ui axio iconfo...
# ..                                                 ...
# 603  100 httpblogjobbolecomtagbook100 issu httpswww...
# 650  build statushttpstravisciorgnusrhackerlawszhsv...
# 662  thecraftofselfteach one futur one couldnt teac...
# 663  logopng github actionshttpsgithubcomcarguogsyg...
# 676  clashchinesepatch httpsimgshieldsiobadgetelegr...
#
#                                             lemmatized
# 18   android codekkcomhttpspcodekkcom english versi...
# 48   kityminder editor kityminder editor fexhttpsgi...
# 49   vuejs httpsgithubcomsqrthreevuejscomponentstyl...
# 52   awesomespider hrefhttpwwwipideanetutmsourcefac...
# 59   vueadmintemplate vue admin element ui axios ic...
# ..                                                 ...
# 603  100 httpblogjobbolecomtagbook100 issue httpsww...
# 650  build statushttpstravisciorgnusrhackerlawszhsv...
# 662  thecraftofselfteaching one future one couldnt ...
# 663  logopng github actionshttpsgithubcomcarguogsyg...
# 676  clashchinesepatch httpsimgshieldsiobadgetelegr...
#
# [68 rows x 6 columns]

# %%
df[df.readme_contents.str.contains('你')].language.value_counts(dropna=False)
# Out:
# NaN           19
# Java          16
# Other         10
# Python        10
# JavaScript     9
# Go             2
# TypeScript     2
# Name: language, dtype: int64

# %%
df[df.readme_contents.str.contains('你')].lemmatized.apply(lambda s: len(s))
# Out:
# 18     95890
# 48      1482
# 49      5558
# 52      5796
# 59      2388
#        ...
# 603    31291
# 650    16077
# 662     2958
# 663     3712
# 676      452
# Name: lemmatized, Length: 68, dtype: int64

# %%
df.lemmatized

# %%
df.language.value_counts(dropna=False, normalize=True)
# Out:
# Other         0.330893
# JavaScript    0.212299
# Python        0.105417
# NaN           0.093704
# TypeScript    0.089312
# Go            0.086384
# Java          0.081991
# Name: language, dtype: float64

# %%
ones = e.get_ngram_frequency(df.lemmatized)

# %%
freq_words = list(ones[ones >1000].index)

# %%
freq_words
# Out:
# ['1',
#  'use',
#  '&#9;',
#  'file',
#  'using',
#  'function',
#  'code',
#  'example',
#  'javascript',
#  'project',
#  '2',
#  'value',
#  'free',
#  'api',
#  'data',
#  'default',
#  'return',
#  'support',
#  'new',
#  'run',
#  'image',
#  'install',
#  'version',
#  'img',
#  'see',
#  'build',
#  'react',
#  'object',
#  'open',
#  'user',
#  'command',
#  'component',
#  'application',
#  '3',
#  'also',
#  'td',
#  'const',
#  'source',
#  'set',
#  'library',
#  'used',
#  'github',
#  'web',
#  'li',
#  'docker',
#  'opensource',
#  'server',
#  'get',
#  'option',
#  'type',
#  'tool',
#  'back',
#  'test',
#  'like',
#  'p',
#  'method',
#  'make',
#  'list',
#  'need',
#  'feature',
#  'c',
#  'name',
#  'de',
#  'one',
#  'python',
#  '0',
#  'window',
#  'number',
#  'add',
#  'import',
#  'let',
#  'create',
#  'string']

# %%
df.language.value_counts(normalize=True)
# Out:
# Other         0.424597
# JavaScript    0.212299
# Python        0.105417
# TypeScript    0.089312
# Go            0.086384
# Java          0.081991
# Name: language, dtype: float64

# %%
for word in freq_words:
    print(f'{word}\n----------------\n{df[df.lemmatized.str.contains(word)].language.value_counts(normalize=True)}\n')
# Out:
# 1
# ----------------
# Other         0.354497
# JavaScript    0.236332
# Python        0.119929
# TypeScript    0.100529
# Go            0.098765
# Java          0.089947
# Name: language, dtype: float64
#
# use
# ----------------
# Other         0.360444
# JavaScript    0.242144
# Python        0.116451
# Go            0.099815
# TypeScript    0.099815
# Java          0.081331
# Name: language, dtype: float64
#
# &#9;
# ----------------
# Other         0.333333
# Java          0.192308
# JavaScript    0.179487
# Go            0.141026
# Python        0.115385
# TypeScript    0.038462
# Name: language, dtype: float64
#
# file
# ----------------
# Other         0.386768
# JavaScript    0.244275
# Python        0.119593
# Go            0.101781
# Java          0.091603
# TypeScript    0.055980
# Name: language, dtype: float64
#
# using
# ----------------
# Other         0.373711
# JavaScript    0.247423
# Python        0.113402
# Go            0.110825
# TypeScript    0.105670
# Java          0.048969
# Name: language, dtype: float64
#
# function
# ----------------
# JavaScript    0.352679
# Other         0.316964
# TypeScript    0.111607
# Python        0.093750
# Go            0.089286
# Java          0.035714
# Name: language, dtype: float64
#
# code
# ----------------
# Other         0.361174
# JavaScript    0.225734
# Python        0.130926
# Go            0.097065
# TypeScript    0.097065
# Java          0.088036
# Name: language, dtype: float64
#
# example
# ----------------
# Other         0.341108
# JavaScript    0.256560
# Python        0.131195
# Go            0.113703
# TypeScript    0.104956
# Java          0.052478
# Name: language, dtype: float64
#
# javascript
# ----------------
# JavaScript    0.547771
# TypeScript    0.178344
# Other         0.171975
# Python        0.044586
# Go            0.038217
# Java          0.019108
# Name: language, dtype: float64
#
# project
# ----------------
# Other         0.369048
# JavaScript    0.233333
# Python        0.119048
# TypeScript    0.102381
# Go            0.100000
# Java          0.076190
# Name: language, dtype: float64
#
# 2
# ----------------
# Other         0.356890
# JavaScript    0.236749
# Python        0.116608
# TypeScript    0.104240
# Java          0.093640
# Go            0.091873
# Name: language, dtype: float64
#
# value
# ----------------
# Other         0.368098
# JavaScript    0.300613
# Go            0.104294
# TypeScript    0.092025
# Python        0.085890
# Java          0.049080
# Name: language, dtype: float64
#
# free
# ----------------
# Other         0.419753
# JavaScript    0.234568
# Python        0.119342
# Go            0.082305
# TypeScript    0.078189
# Java          0.065844
# Name: language, dtype: float64
#
# api
# ----------------
# Other         0.304598
# JavaScript    0.261494
# TypeScript    0.126437
# Go            0.114943
# Python        0.103448
# Java          0.089080
# Name: language, dtype: float64
#
# data
# ----------------
# Other         0.331058
# JavaScript    0.235495
# Python        0.156997
# Go            0.126280
# TypeScript    0.085324
# Java          0.064846
# Name: language, dtype: float64
#
# default
# ----------------
# Other         0.372807
# JavaScript    0.258772
# Python        0.122807
# Go            0.100877
# TypeScript    0.087719
# Java          0.057018
# Name: language, dtype: float64
#
# return
# ----------------
# Other         0.308642
# JavaScript    0.296296
# TypeScript    0.117284
# Python        0.111111
# Go            0.092593
# Java          0.074074
# Name: language, dtype: float64
#
# support
# ----------------
# Other         0.334171
# JavaScript    0.248744
# Python        0.120603
# TypeScript    0.118090
# Go            0.115578
# Java          0.062814
# Name: language, dtype: float64
#
# new
# ----------------
# Other         0.348168
# JavaScript    0.253927
# Python        0.123037
# TypeScript    0.104712
# Go            0.096859
# Java          0.073298
# Name: language, dtype: float64
#
# run
# ----------------
# Other         0.361039
# JavaScript    0.244156
# Python        0.129870
# Go            0.116883
# TypeScript    0.101299
# Java          0.046753
# Name: language, dtype: float64
#
# image
# ----------------
# Other         0.333333
# JavaScript    0.221122
# Python        0.151815
# TypeScript    0.105611
# Go            0.102310
# Java          0.085809
# Name: language, dtype: float64
#
# install
# ----------------
# Other         0.348730
# JavaScript    0.270208
# Python        0.138568
# Go            0.110855
# TypeScript    0.096998
# Java          0.034642
# Name: language, dtype: float64
#
# version
# ----------------
# Other         0.335
# JavaScript    0.245
# Python        0.125
# TypeScript    0.110
# Go            0.100
# Java          0.085
# Name: language, dtype: float64
#
# img
# ----------------
# Other         0.314607
# JavaScript    0.253933
# TypeScript    0.121348
# Python        0.119101
# Go            0.098876
# Java          0.092135
# Name: language, dtype: float64
#
# see
# ----------------
# Other         0.366412
# JavaScript    0.221374
# Python        0.119593
# TypeScript    0.117048
# Go            0.109415
# Java          0.066158
# Name: language, dtype: float64
#
# build
# ----------------
# Other         0.341584
# JavaScript    0.240099
# TypeScript    0.111386
# Go            0.108911
# Python        0.101485
# Java          0.096535
# Name: language, dtype: float64
#
# react
# ----------------
# JavaScript    0.373913
# TypeScript    0.330435
# Other         0.208696
# Java          0.043478
# Go            0.034783
# Python        0.008696
# Name: language, dtype: float64
#
# object
# ----------------
# JavaScript    0.316770
# Other         0.304348
# Python        0.149068
# TypeScript    0.105590
# Go            0.074534
# Java          0.049689
# Name: language, dtype: float64
#
# open
# ----------------
# Other         0.345865
# JavaScript    0.245614
# TypeScript    0.122807
# Python        0.117794
# Go            0.100251
# Java          0.067669
# Name: language, dtype: float64
#
# user
# ----------------
# Other         0.341969
# JavaScript    0.240933
# Python        0.124352
# TypeScript    0.119171
# Go            0.113990
# Java          0.059585
# Name: language, dtype: float64
#
# command
# ----------------
# Other         0.371981
# JavaScript    0.227053
# Python        0.164251
# Go            0.125604
# TypeScript    0.072464
# Java          0.038647
# Name: language, dtype: float64
#
# component
# ----------------
# Other         0.350649
# JavaScript    0.285714
# TypeScript    0.168831
# Go            0.071429
# Java          0.064935
# Python        0.058442
# Name: language, dtype: float64
#
# application
# ----------------
# Other         0.359504
# JavaScript    0.243802
# Go            0.140496
# Python        0.086777
# TypeScript    0.086777
# Java          0.082645
# Name: language, dtype: float64
#
# 3
# ----------------
# Other         0.347349
# JavaScript    0.234004
# Python        0.122486
# TypeScript    0.102377
# Go            0.096892
# Java          0.096892
# Name: language, dtype: float64
#
# also
# ----------------
# Other         0.351613
# JavaScript    0.248387
# Python        0.141935
# Go            0.125806
# TypeScript    0.093548
# Java          0.038710
# Name: language, dtype: float64
#
# td
# ----------------
# Other         0.344118
# JavaScript    0.250000
# Python        0.138235
# TypeScript    0.105882
# Go            0.091176
# Java          0.070588
# Name: language, dtype: float64
#
# const
# ----------------
# JavaScript    0.384615
# Other         0.251748
# TypeScript    0.174825
# Python        0.104895
# Go            0.041958
# Java          0.041958
# Name: language, dtype: float64
#
# source
# ----------------
# Other         0.354523
# JavaScript    0.237164
# Python        0.119804
# Go            0.102689
# TypeScript    0.102689
# Java          0.083130
# Name: language, dtype: float64
#
# set
# ----------------
# Other         0.358140
# JavaScript    0.255814
# Python        0.118605
# TypeScript    0.106977
# Go            0.090698
# Java          0.069767
# Name: language, dtype: float64
#
# library
# ----------------
# Other         0.361868
# JavaScript    0.241245
# TypeScript    0.116732
# Python        0.108949
# Go            0.101167
# Java          0.070039
# Name: language, dtype: float64
#
# used
# ----------------
# Other         0.372180
# JavaScript    0.225564
# Python        0.150376
# TypeScript    0.097744
# Go            0.090226
# Java          0.063910
# Name: language, dtype: float64
#
# github
# ----------------
# Other         0.350427
# JavaScript    0.241026
# Python        0.117949
# TypeScript    0.100855
# Go            0.095726
# Java          0.094017
# Name: language, dtype: float64
#
# web
# ----------------
# Other         0.311978
# JavaScript    0.295265
# TypeScript    0.111421
# Python        0.108635
# Go            0.105850
# Java          0.066852
# Name: language, dtype: float64
#
# li
# ----------------
# Other         0.358932
# JavaScript    0.240401
# Python        0.118531
# TypeScript    0.096828
# Go            0.095159
# Java          0.090150
# Name: language, dtype: float64
#
# docker
# ----------------
# Other         0.304348
# Go            0.260870
# Python        0.195652
# JavaScript    0.141304
# TypeScript    0.054348
# Java          0.043478
# Name: language, dtype: float64
#
# opensource
# ----------------
# Other         0.316176
# JavaScript    0.272059
# Go            0.132353
# TypeScript    0.132353
# Python        0.095588
# Java          0.051471
# Name: language, dtype: float64
#
# server
# ----------------
# JavaScript    0.312195
# Other         0.268293
# Go            0.131707
# TypeScript    0.121951
# Python        0.107317
# Java          0.058537
# Name: language, dtype: float64
#
# get
# ----------------
# Other         0.352201
# JavaScript    0.257862
# Python        0.113208
# TypeScript    0.109015
# Go            0.102725
# Java          0.064990
# Name: language, dtype: float64
#
# option
# ----------------
# Other         0.344978
# JavaScript    0.296943
# Python        0.131004
# Go            0.100437
# TypeScript    0.091703
# Java          0.034934
# Name: language, dtype: float64
#
# type
# ----------------
# Other         0.333333
# JavaScript    0.297872
# TypeScript    0.117021
# Go            0.106383
# Python        0.074468
# Java          0.070922
# Name: language, dtype: float64
#
# tool
# ----------------
# Other         0.335793
# JavaScript    0.254613
# Python        0.136531
# Go            0.118081
# TypeScript    0.114391
# Java          0.040590
# Name: language, dtype: float64
#
# back
# ----------------
# Other         0.370607
# JavaScript    0.287540
# TypeScript    0.108626
# Python        0.095847
# Go            0.086262
# Java          0.051118
# Name: language, dtype: float64
#
# test
# ----------------
# Other         0.312808
# JavaScript    0.251232
# Python        0.135468
# Go            0.115764
# TypeScript    0.115764
# Java          0.068966
# Name: language, dtype: float64
#
# like
# ----------------
# Other         0.382979
# JavaScript    0.237082
# TypeScript    0.115502
# Python        0.112462
# Go            0.109422
# Java          0.042553
# Name: language, dtype: float64
#
# p
# ----------------
# Other         0.360656
# JavaScript    0.237705
# Python        0.116393
# TypeScript    0.100000
# Go            0.093443
# Java          0.091803
# Name: language, dtype: float64
#
# method
# ----------------
# Other         0.325301
# JavaScript    0.295181
# Python        0.138554
# Go            0.096386
# TypeScript    0.084337
# Java          0.060241
# Name: language, dtype: float64
#
# make
# ----------------
# Other         0.399371
# JavaScript    0.232704
# Python        0.119497
# Go            0.106918
# TypeScript    0.084906
# Java          0.056604
# Name: language, dtype: float64
#
# list
# ----------------
# Other         0.321101
# JavaScript    0.238532
# Go            0.134557
# Python        0.128440
# Java          0.088685
# TypeScript    0.088685
# Name: language, dtype: float64
#
# need
# ----------------
# Other         0.368421
# JavaScript    0.276316
# Python        0.121711
# Go            0.101974
# TypeScript    0.101974
# Java          0.029605
# Name: language, dtype: float64
#
# feature
# ----------------
# Other         0.352564
# JavaScript    0.243590
# Go            0.131410
# TypeScript    0.125000
# Python        0.102564
# Java          0.044872
# Name: language, dtype: float64
#
# c
# ----------------
# Other         0.361702
# JavaScript    0.237316
# Python        0.116203
# TypeScript    0.099836
# Go            0.093290
# Java          0.091653
# Name: language, dtype: float64
#
# name
# ----------------
# Other         0.329861
# JavaScript    0.267361
# Python        0.131944
# Go            0.114583
# TypeScript    0.090278
# Java          0.065972
# Name: language, dtype: float64
#
# de
# ----------------
# Other         0.360000
# JavaScript    0.238333
# Python        0.116667
# TypeScript    0.100000
# Go            0.095000
# Java          0.090000
# Name: language, dtype: float64
#
# one
# ----------------
# Other         0.355748
# JavaScript    0.258134
# Python        0.112798
# TypeScript    0.104121
# Go            0.095445
# Java          0.073753
# Name: language, dtype: float64
#
# python
# ----------------
# Python        0.442029
# Other         0.355072
# JavaScript    0.072464
# Java          0.057971
# Go            0.050725
# TypeScript    0.021739
# Name: language, dtype: float64
#
# 0
# ----------------
# Other         0.357522
# JavaScript    0.244248
# Python        0.115044
# TypeScript    0.100885
# Go            0.093805
# Java          0.088496
# Name: language, dtype: float64
#
# window
# ----------------
# Other         0.406091
# JavaScript    0.258883
# Python        0.126904
# Go            0.101523
# TypeScript    0.060914
# Java          0.045685
# Name: language, dtype: float64
#
# number
# ----------------
# Other         0.348315
# JavaScript    0.292135
# Python        0.140449
# Go            0.112360
# TypeScript    0.073034
# Java          0.033708
# Name: language, dtype: float64
#
# add
# ----------------
# Other         0.379052
# JavaScript    0.269327
# Go            0.099751
# Python        0.097257
# TypeScript    0.087282
# Java          0.067332
# Name: language, dtype: float64
#
# import
# ----------------
# Other         0.294643
# JavaScript    0.272321
# Python        0.165179
# TypeScript    0.138393
# Go            0.080357
# Java          0.049107
# Name: language, dtype: float64
#
# let
# ----------------
# Other         0.361272
# JavaScript    0.265896
# Python        0.115607
# Go            0.106936
# TypeScript    0.101156
# Java          0.049133
# Name: language, dtype: float64
#
# create
# ----------------
# Other         0.375000
# JavaScript    0.270270
# TypeScript    0.128378
# Python        0.091216
# Go            0.081081
# Java          0.054054
# Name: language, dtype: float64
#
# string
# ----------------
# JavaScript    0.333333
# Other         0.306122
# Go            0.108844
# Java          0.095238
# Python        0.081633
# TypeScript    0.074830
# Name: language, dtype: float64

# %% [markdown]
# takeout javascript

# %%
strong = pd.DataFrame()
for word in freq_words:
    strong[word] = df[df.lemmatized.str.contains(word)].language.value_counts(normalize=True)

# %%
high_freq = strong[strong >.35]

# %%
pd.options.display.max_columns = None

# %%
high_freq
# Out:
#                    1       use  &#9;      file     using  function      code  \
# Other       0.354497  0.360444   NaN  0.386768  0.373711       NaN  0.361174
# JavaScript       NaN       NaN   NaN       NaN       NaN  0.352679       NaN
# Python           NaN       NaN   NaN       NaN       NaN       NaN       NaN
# TypeScript       NaN       NaN   NaN       NaN       NaN       NaN       NaN
# Go               NaN       NaN   NaN       NaN       NaN       NaN       NaN
# Java             NaN       NaN   NaN       NaN       NaN       NaN       NaN
#
#             example  javascript   project        2     value      free  api  \
# Other           NaN         NaN  0.369048  0.35689  0.368098  0.419753  NaN
# JavaScript      NaN    0.547771       NaN      NaN       NaN       NaN  NaN
# Python          NaN         NaN       NaN      NaN       NaN       NaN  NaN
# TypeScript      NaN         NaN       NaN      NaN       NaN       NaN  NaN
# Go              NaN         NaN       NaN      NaN       NaN       NaN  NaN
# Java            NaN         NaN       NaN      NaN       NaN       NaN  NaN
#
#             data   default  return  support  new       run  image  install  \
# Other        NaN  0.372807     NaN      NaN  NaN  0.361039    NaN      NaN
# JavaScript   NaN       NaN     NaN      NaN  NaN       NaN    NaN      NaN
# Python       NaN       NaN     NaN      NaN  NaN       NaN    NaN      NaN
# TypeScript   NaN       NaN     NaN      NaN  NaN       NaN    NaN      NaN
# Go           NaN       NaN     NaN      NaN  NaN       NaN    NaN      NaN
# Java         NaN       NaN     NaN      NaN  NaN       NaN    NaN      NaN
#
#             version  img       see  build     react  object  open  user  \
# Other           NaN  NaN  0.366412    NaN       NaN     NaN   NaN   NaN
# JavaScript      NaN  NaN       NaN    NaN  0.373913     NaN   NaN   NaN
# Python          NaN  NaN       NaN    NaN       NaN     NaN   NaN   NaN
# TypeScript      NaN  NaN       NaN    NaN       NaN     NaN   NaN   NaN
# Go              NaN  NaN       NaN    NaN       NaN     NaN   NaN   NaN
# Java            NaN  NaN       NaN    NaN       NaN     NaN   NaN   NaN
#
#              command  component  application   3      also  td     const  \
# Other       0.371981   0.350649     0.359504 NaN  0.351613 NaN       NaN
# JavaScript       NaN        NaN          NaN NaN       NaN NaN  0.384615
# Python           NaN        NaN          NaN NaN       NaN NaN       NaN
# TypeScript       NaN        NaN          NaN NaN       NaN NaN       NaN
# Go               NaN        NaN          NaN NaN       NaN NaN       NaN
# Java             NaN        NaN          NaN NaN       NaN NaN       NaN
#
#               source      set   library     used    github  web        li  \
# Other       0.354523  0.35814  0.361868  0.37218  0.350427  NaN  0.358932
# JavaScript       NaN      NaN       NaN      NaN       NaN  NaN       NaN
# Python           NaN      NaN       NaN      NaN       NaN  NaN       NaN
# TypeScript       NaN      NaN       NaN      NaN       NaN  NaN       NaN
# Go               NaN      NaN       NaN      NaN       NaN  NaN       NaN
# Java             NaN      NaN       NaN      NaN       NaN  NaN       NaN
#
#             docker  opensource  server       get  option  type  tool  \
# Other          NaN         NaN     NaN  0.352201     NaN   NaN   NaN
# JavaScript     NaN         NaN     NaN       NaN     NaN   NaN   NaN
# Python         NaN         NaN     NaN       NaN     NaN   NaN   NaN
# TypeScript     NaN         NaN     NaN       NaN     NaN   NaN   NaN
# Go             NaN         NaN     NaN       NaN     NaN   NaN   NaN
# Java           NaN         NaN     NaN       NaN     NaN   NaN   NaN
#
#                 back  test      like         p  method      make  list  \
# Other       0.370607   NaN  0.382979  0.360656     NaN  0.399371   NaN
# JavaScript       NaN   NaN       NaN       NaN     NaN       NaN   NaN
# Python           NaN   NaN       NaN       NaN     NaN       NaN   NaN
# TypeScript       NaN   NaN       NaN       NaN     NaN       NaN   NaN
# Go               NaN   NaN       NaN       NaN     NaN       NaN   NaN
# Java             NaN   NaN       NaN       NaN     NaN       NaN   NaN
#
#                 need   feature         c  name    de       one    python  \
# Other       0.368421  0.352564  0.361702   NaN  0.36  0.355748  0.355072
# JavaScript       NaN       NaN       NaN   NaN   NaN       NaN       NaN
# Python           NaN       NaN       NaN   NaN   NaN       NaN  0.442029
# TypeScript       NaN       NaN       NaN   NaN   NaN       NaN       NaN
# Go               NaN       NaN       NaN   NaN   NaN       NaN       NaN
# Java             NaN       NaN       NaN   NaN   NaN       NaN       NaN
#
#                    0    window  number       add  import       let  create  \
# Other       0.357522  0.406091     NaN  0.379052     NaN  0.361272   0.375
# JavaScript       NaN       NaN     NaN       NaN     NaN       NaN     NaN
# Python           NaN       NaN     NaN       NaN     NaN       NaN     NaN
# TypeScript       NaN       NaN     NaN       NaN     NaN       NaN     NaN
# Go               NaN       NaN     NaN       NaN     NaN       NaN     NaN
# Java             NaN       NaN     NaN       NaN     NaN       NaN     NaN
#
#             string
# Other          NaN
# JavaScript     NaN
# Python         NaN
# TypeScript     NaN
# Go             NaN
# Java           NaN

# %%
high_freq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# CategoricalIndex: 6 entries, Other to Java
# Data columns (total 73 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   1            1 non-null      float64
#  1   use          1 non-null      float64
#  2   &#9;         1 non-null      float64
#  3   file         1 non-null      float64
#  4   using        1 non-null      float64
#  5   function     1 non-null      float64
#  6   code         1 non-null      float64
#  7   example      1 non-null      float64
#  8   javascript   1 non-null      float64
#  9   project      1 non-null      float64
#  10  2            1 non-null      float64
#  11  value        1 non-null      float64
#  12  free         1 non-null      float64
#  13  api          1 non-null      float64
#  14  data         1 non-null      float64
#  15  default      1 non-null      float64
#  16  return       0 non-null      float64
#  17  support      1 non-null      float64
#  18  new          1 non-null      float64
#  19  run          1 non-null      float64
#  20  image        1 non-null      float64
#  21  install      1 non-null      float64
#  22  version      1 non-null      float64
#  23  img          1 non-null      float64
#  24  see          1 non-null      float64
#  25  build        1 non-null      float64
#  26  react        0 non-null      float64
#  27  object       1 non-null      float64
#  28  open         1 non-null      float64
#  29  user         1 non-null      float64
#  30  command      1 non-null      float64
#  31  component    1 non-null      float64
#  32  application  1 non-null      float64
#  33  3            1 non-null      float64
#  34  also         1 non-null      float64
#  35  td           1 non-null      float64
#  36  const        0 non-null      float64
#  37  source       1 non-null      float64
#  38  set          1 non-null      float64
#  39  library      1 non-null      float64
#  40  used         1 non-null      float64
#  41  github       1 non-null      float64
#  42  web          1 non-null      float64
#  43  li           1 non-null      float64
#  44  docker       1 non-null      float64
#  45  opensource   1 non-null      float64
#  46  server       1 non-null      float64
#  47  get          1 non-null      float64
#  48  option       1 non-null      float64
#  49  type         1 non-null      float64
#  50  tool         1 non-null      float64
#  51  back         1 non-null      float64
#  52  test         1 non-null      float64
#  53  like         1 non-null      float64
#  54  p            1 non-null      float64
#  55  method       1 non-null      float64
#  56  make         1 non-null      float64
#  57  list         1 non-null      float64
#  58  need         1 non-null      float64
#  59  feature      1 non-null      float64
#  60  c            1 non-null      float64
#  61  name         1 non-null      float64
#  62  de           1 non-null      float64
#  63  one          1 non-null      float64
#  64  python       2 non-null      float64
#  65  0            1 non-null      float64
#  66  window       1 non-null      float64
#  67  number       1 non-null      float64
#  68  add          1 non-null      float64
#  69  import       1 non-null      float64
#  70  let          1 non-null      float64
#  71  create       1 non-null      float64
#  72  string       1 non-null      float64
# dtypes: float64(73)
# memory usage: 3.6 KB

# %%
word
# Out:
# 'library'

# %%
bigrams = e.get_ngram_frequency(df.lemmatized, 2)

# %%
bigrams = pd.DataFrame(bigrams)

# %%
df[df.lemmatized.str.contains("javascript")].language.value_counts(normalize=True)
# Out:
# JavaScript      0.547771
# TypeScript      0.178344
# Python          0.044586
# Go              0.038217
# HTML            0.031847
# C++             0.031847
# Java            0.019108
# C#              0.012739
# CSS             0.012739
# Vue             0.012739
# Ruby            0.012739
# Rust            0.012739
# Svelte          0.006369
# Mustache        0.006369
# CoffeeScript    0.006369
# Elixir          0.006369
# Vim script      0.006369
# WebAssembly     0.006369
# C               0.006369
# Name: language, dtype: float64
